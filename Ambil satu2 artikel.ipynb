# %%
from newspaper import Article
# https://www.geeksforgeeks.org/newspaper-article-scraping-curation-python/
# https://pypi.org/project/newspaper3k/
# https://newspaper.readthedocs.io/en/latest/
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1c14162a643e> in <module>()
# ----> 1 from newspaper import Article
#       2 # https://www.geeksforgeeks.org/newspaper-article-scraping-curation-python/
#       3 # https://pypi.org/project/newspaper3k/
#       4 # https://newspaper.readthedocs.io/en/latest/
#
# ModuleNotFoundError: No module named 'newspaper'

# %%
#A new article from Kompas
url = "http://www.tribunnews.com/bisnis/2019/02/22/ojk-usul-p2p-lending-pakai-layanan-asuransi-ini-alasannya"

article = Article(url)

# %%
#To download the article 
article.download()
article.html
# Out:
# '<!DOCTYPE html>\n<html lang="id-ID" itemscope="itemscope" itemtype="http://schema.org/WebPage">\n<head>\n<title>OJK Usul P2P Lending Pakai Layanan Asuransi, Ini Alasannya - Tribunnews.com</title>\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<meta name="description" content="Ada musabab dibalik peran asuransi, yakni mengatasi penunggakan pengembalian dari peminjam sehingga tidak terjadi penarikan tak etis" />\n<meta name="news_keywords" content="OJK, Wimboh Santoso, Victor Timothy, Finansial, Bisnis" />\n<meta http-equiv="Refresh" content="900" />\n<meta name="google-site-verification" content="m1rJaolRgi4KZ_yfD1gNchBXhcW0dpgVP97v4gT55P4" />\n<meta name="dailymotion-domain-verification" content="dm8nev8vlpec4cpb7" />\n<meta name="alexaVerifyID" content="MfaOlsq5CrV93W9N8QdIqIqBKxI"/>\n<meta name="robots" content="index,follow"/>\n<meta name="googlebot-news" content="index,follow"/>\n<meta
# ...

# %%
#To parse the article 
article.parse()
article.authors
# Out:
# []

# %%
article.publish_date
# Out:
# datetime.datetime(2019, 2, 22, 0, 0)

# %%
article.text
# Out:
# 'TRIBUNNEWS.COM, JAKARTA - Deputi Direktur Pengaturan Penelitian dan Pengembangan Fintech Otoritas Jasa Keuangan (OJK) Munawar Kasan menganjurkan layanan pinjaman online atau peer to peer (P2P) lending harus disertai asuransi.\n\nAda musabab dibalik peran asuransi, yakni mengatasi penunggakan pengembalian dari peminjam sehingga tidak terjadi penarikan tak etis.\n\n"Jadi kalau ada penunggukan asuransi yang bayar. Ini menyusul banyaknya laporan penarikan dana paksa (oleh debt collector)," katanya saat diskusi dengan asosiasi dan pelaku bisnis fintech kemarin, (21/2/2019).\n\nBaca: Guardiola Mengaku Butuh 3 Bintang Barcelona untuk Bisa Juara Liga Champions\n\nHal yang sama kerap disampaikan Kepala Dewan Komisioner OJK Wimboh Santoso bahwa dalam melakukan transaksi kredit melalui fintech peer to peer (P2P) lending masyarakat harus berhati-hati\n\nWimboh mengatakan masyarakat harus dapat membedakan antara fintech lending yang ilegal dengan yang ilegal.\n\nPasalnya, minimnya pengetahuan me
# ...

# %%
article.top_image
# Out:
# 'http://cdn2.tstatic.net/tribunnews/foto/bank/images/fintech__2.jpg'

# %%
article.movies
# Out:
# []

# %%
article.nlp()

# %%
article.keywords
# Out:
# ['dan',
#  'ini',
#  'terdaftar',
#  'fintech',
#  'pendanaan',
#  'p2p',
#  'alasannya',
#  'yang',
#  'masyarakat',
#  'layanan',
#  'pinjaman',
#  'ojk',
#  'pakai',
#  'lending',
#  'dengan',
#  'usul',
#  'asuransi']

# %%
article.summary
# Out:
# 'TRIBUNNEWS.COM, JAKARTA - Deputi Direktur Pengaturan Penelitian dan Pengembangan Fintech Otoritas Jasa Keuangan (OJK) Munawar Kasan menganjurkan layanan pinjaman online atau peer to peer (P2P) lending harus disertai asuransi.\nKalau yang terdaftar kalau ada nasabah yang mempunyai pinjaman kita bisa tahu siapa fintech yang memberikan pinjaman," ujar WimbohDari sisi pelaku bisnis yang telah terdaftar di OJK, bahwa P2P lending saat ini sangat dibutuhkan oleh masyarakat.\n"Fintech P2P Lending hadir dengan visi untuk membebaskan masyarakat Indonesia dari masalah finansial.\nSelain itu Andrisyah Tauladan, Direktur Asetku, juga mengungkapkan dukungannya terhadap tumbuhnya industri fintech, khususnya sektor fintech p2p lending, di Indonesia karena dapat memberikan dampak yang begitu besar bagi masyarakat Indonesia.\n"Kami melihat bahwa kedepannya sektor fintech p2p lending akan semakin berkembang di Indonesia karena kebutuhan yang memang tinggi dari masyarakat terhadap sumber pendanaan alte
# ...

# %% [markdown]
# # 1

# %%
#A new article from tribunnews
# http://www.tribunnews.com/search?q=P2P+Lending
# JSON! Google Search
url = "http://www.tribunnews.com/bisnis/2019/02/22/ojk-usul-p2p-lending-pakai-layanan-asuransi-ini-alasannya"
  
#For different language newspaper refer above table 
toi_article = Article(url) # en for English 
  
#To download the article 
toi_article.download() 
  
#To parse the article 
toi_article.parse() 
  
#To perform natural language processing ie..nlp 
toi_article.nlp() 
  
#To extract title 
print("Article's Title:") 
print(toi_article.title) 
print("------")

#To extract publish_date 
print("Article's Publish Date:") 
print(toi_article.publish_date) 
print("------")

#To extract authors 
print("Article's Authors:") 
print(toi_article.authors) 
print("------")
  
#To extract text 
print("Article's Text:") 
print(toi_article.text) 
print("------") 
  
#To extract summary 
print("Article's Summary:") 
print(toi_article.summary) 
print("------") 
  
#To extract keywords 
print("Article's Keywords:") 
print(toi_article.keywords)
# Out:
# Article's Title:
# OJK Usul P2P Lending Pakai Layanan Asuransi, Ini Alasannya
# ------
# Article's Publish Date:
# 2019-02-22 00:00:00
# ------
# Article's Authors:
# []
# ------
# Article's Text:
# TRIBUNNEWS.COM, JAKARTA - Deputi Direktur Pengaturan Penelitian dan Pengembangan Fintech Otoritas Jasa Keuangan (OJK) Munawar Kasan menganjurkan layanan pinjaman online atau peer to peer (P2P) lending harus disertai asuransi.
#
# Ada musabab dibalik peran asuransi, yakni mengatasi penunggakan pengembalian dari peminjam sehingga tidak terjadi penarikan tak etis.
#
# "Jadi kalau ada penunggukan asuransi yang bayar. Ini menyusul banyaknya laporan penarikan dana paksa (oleh debt collector)," katanya saat diskusi dengan asosiasi dan pelaku bisnis fintech kemarin, (21/2/2019).
#
# Baca: Guardiola Mengaku Butuh 3 Bintang Barcelona untuk Bisa Juara Liga Champions
#
# ...

# %% [markdown]
# # 2

# %%
#A new article from okezone
# https://search.okezone.com/search?q=P2P%20Lending
# JSON!
url = "https://economy.okezone.com/read/2019/05/04/320/2051526/transaksi-pinjaman-online-tembus-rp33-2-triliun-pada-maret-2019"
  
#For different language newspaper refer above table 
toi_article = Article(url)
  
#To download the article 
toi_article.download() 
  
#To parse the article 
toi_article.parse() 
  
#To perform natural language processing ie..nlp 
toi_article.nlp() 
  
#To extract title 
print("Article's Title:") 
print(toi_article.title) 
print("------")

#To extract publish_date 
print("Article's Publish Date:") 
print(toi_article.publish_date) 
print("------")

#To extract authors 
print("Article's Authors:") 
print(toi_article.authors) 
print("------")
  
#To extract text 
print("Article's Text:") 
print(toi_article.text) 
print("------") 
  
#To extract summary 
print("Article's Summary:") 
print(toi_article.summary) 
print("------") 
  
#To extract keywords 
print("Article's Keywords:") 
print(toi_article.keywords)
# Out:
# Article's Title:
# Transaksi Pinjaman Online Tembus Rp33,2 Triliun pada Maret 2019 : Okezone Economy
# ------
# Article's Publish Date:
# 2019-05-04 00:00:00
# ------
# Article's Authors:
# []
# ------
# Article's Text:
# JAKARTA – Otoritas Jasa Keuangan (OJK) mencatat, transaksi pinjaman online mencapai Rp33,2 triliun hingga Maret 2019. Berdasarkan data OJK, per Maret lalu jumlah pinjaman daring disalurkan kepada 6,96 juta peminjam.
#
# Deputi Komisioner OJK Institute dan Keuangan Digital Sukarela Batunanggar mengatakan, jumlah rekening peminjam online juga tercatat naik 59,70% dibanding awal tahun ini.
#
# “Perusahaan fintech P2P lending sudah mencapai 106 yang berizin di OJK. Jumlah itu 49% dari total 207 fintech yang terdaftar,” ujar Sukarela kemarin dalam diskusi bersama media di Bandung, Jawa Barat.
#
# ...

# %% [markdown]
# # 3

# %%
#A new article from sindonews
# https://search.sindonews.com/search?type=artikel&q=p2p+lending
# sampai kelipatan 12 dari jumlah berita yang ada di Hasil Pencarian 
# https://search.sindonews.com/search/12?type=artikel&q=p2p+lending
# https://search.sindonews.com/search/24?type=artikel&q=p2p+lending
url = "https://ekbis.sindonews.com/read/1401189/178/fintech-p2p-lending-salurkan-pinjaman-rp332-t-hingga-kuartal-i2019-1556888614"
  
#For different language newspaper refer above table 
toi_article = Article(url)
  
#To download the article 
toi_article.download() 
  
#To parse the article 
toi_article.parse() 
  
#To perform natural language processing ie..nlp 
toi_article.nlp() 
  
#To extract title 
print("Article's Title:") 
print(toi_article.title) 
print("------")

#To extract publish_date 
print("Article's Publish Date:") 
print(toi_article.publish_date) 
print("------")

#To extract authors 
print("Article's Authors:") 
print(toi_article.authors) 
print("------")
  
#To extract text 
print("Article's Text:") 
print(toi_article.text) 
print("------") 
  
#To extract summary 
print("Article's Summary:") 
print(toi_article.summary) 
print("------") 
  
#To extract keywords 
print("Article's Keywords:") 
print(toi_article.keywords)
# Out:
# Article's Title:
# Fintech P2P Lending Salurkan Pinjaman Rp33,2 T hingga Kuartal I/2019
# ------
# Article's Publish Date:
# None
# ------
# Article's Authors:
# ['Hafid Fuad']
# ------
# Article's Text:
# loading...
#
# (fjo)
#
# ...

# %% [markdown]
# # 4

# %%
#A new article from mediaindonesia
# https://mediaindonesia.com/search?q=P2P+Lending
# JSON! Google Search
url = "https://mediaindonesia.com/read/detail/204613-tindak-tegas-p2p-lending-yang-melanggar"
  
#For different language newspaper refer above table 
toi_article = Article(url)
  
#To download the article 
toi_article.download() 
  
#To parse the article 
toi_article.parse() 
  
#To perform natural language processing ie..nlp 
toi_article.nlp() 
  
#To extract title 
print("Article's Title:") 
print(toi_article.title) 
print("------")

#To extract publish_date 
print("Article's Publish Date:") 
print(toi_article.publish_date) 
print("------")

#To extract authors 
print("Article's Authors:") 
print(toi_article.authors) 
print("------")
  
#To extract text 
print("Article's Text:") 
print(toi_article.text) 
print("------") 
  
#To extract summary 
print("Article's Summary:") 
print(toi_article.summary) 
print("------") 
  
#To extract keywords 
print("Article's Keywords:") 
print(toi_article.keywords)
# Out:
# Article's Title:
# Tindak Tegas P2P Lending yang Melanggar
# ------
# Article's Publish Date:
# 2018-12-17 04:30:58+07:00
# ------
# Article's Authors:
# ['Mediaindonesia.Com Developer']
# ------
# Article's Text:
# OTORITAS Jasa Keuangan (OJK) memastikan akan melakukan tindakan tegas terhadap penyelenggara teknologi finansial (tekfin) berbasis pinjam-meminjam antarpihak (P2P lending) yang telah terdaftar atau berizin, jika terbukti melakukan pelanggaran. Bagi penyelenggaraan P2P ilegal, OJK melalui Satuan Tugas Waspada Investasi bakal melakukan sejumlah tindakan untuk memutus mata rantai aliran dana.
#
# Keberadaan P2P lending merupakan bentuk alternatif pendanaan yang mempermudah akses keuangan masyarakat. Tapi, masyarakat harus benar-benar memahami risiko, kewajiban, dan biaya saat berinteraksi dengan platform tersebut, sehingga terhindar dari hal yang merugikan.
#
# ...

# %% [markdown]
# # 5

# %%
#A new article from katadata
# https://katadata.co.id/search/cse/p2p%20lending/-/-/-/-/-/-/0
# sampai
# https://katadata.co.id/search/cse/p2p%20lending/-/-/-/-/-/-/10
# url = "https://katadata.co.id/berita/2019/05/10/pasang-bunga-pinjaman-melebihi-batas-izin-2-fintech-terancam-dicabut"
url = "https://finance.detik.com/fintech/d-4530364/ri-diserbu-fintech-abal-abal-dari-china?_ga=2.128981900.1856493075.1557995319-455813152.1557689991"
  
#For different language newspaper refer above table 
toi_article = Article(url)
  
#To download the article 
toi_article.download() 
  
#To parse the article 
toi_article.parse() 
  
#To perform natural language processing ie..nlp 
toi_article.nlp() 
  
#To extract title 
print("Article's Title:") 
print(toi_article.title) 
print("------")

#To extract publish_date 
print("Article's Publish Date:") 
print(toi_article.publish_date) 
print("------")

#To extract authors 
print("Article's Authors:") 
print(toi_article.authors) 
print("------")
  
#To extract text 
print("Article's Text:") 
print(toi_article.text) 
print("------") 
  
#To extract summary 
print("Article's Summary:") 
print(toi_article.summary) 
print("------") 
  
#To extract keywords 
print("Article's Keywords:") 
print(toi_article.keywords)
# Out:
# Article's Title:
# RI Diserbu Fintech Abal-abal dari China
# ------
# Article's Publish Date:
# 2019-04-30 11:46:05
# ------
# Article's Authors:
# ['Sylke Febrina Laucereno', 'Https', 'Www.Facebook.Com Detikfinance', 'Sylke Febrina Laucereno - Detikfinance']
# ------
# Article's Text:
#
# ------
# Article's Summary:
#
# ------
# Article's Keywords:
# ['fintech', 'dari', 'ri', 'abalabal', 'china', 'diserbu']
